# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=Boston"
city_url
city_weather = requests.get(city_url).json()
city_description = city_weather["weather"][0]["description"]
city_country
# Out:
# 'scattered clouds'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | deputatskiy
# Processing Record 3 of Set 1 | teguldet
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | najran
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | natchez
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 1 | chateaubelair
# Processing Record 15 of Set 1 | lavrentiya
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | aklavik
# Processing Record 21 of Set 1 | southbridge
# Processing Record 22 of Set 1 | balaipungut
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | yulara
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | vila velha
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | stornoway
# Processing Record 32 of Set 1 | catuday
# Processing Record 33 of Set 1 | jalgaon
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | lorengau
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | lasa
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | shaghat
# Processing Record 45 of Set 1 | vestmanna
# Processing Record 46 of Set 1 | buda
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 2 | naze
# Processing Record 2 of Set 2 | mezen
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | kuopio
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | inirida
# Processing Record 10 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | san cristobal
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | obera
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | daru
# Processing Record 17 of Set 2 | ozernovskiy
# Processing Record 18 of Set 2 | ahuimanu
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | yuancheng
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | eidsvoll
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | mao
# Processing Record 26 of Set 2 | samarai
# Processing Record 27 of Set 2 | bamut
# Processing Record 28 of Set 2 | soe
# Processing Record 29 of Set 2 | sorkjosen
# Processing Record 30 of Set 2 | mehamn
# Processing Record 31 of Set 2 | humaita
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | nouadhibou
# Processing Record 34 of Set 2 | clyde river
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | saint anthony
# Processing Record 39 of Set 2 | mazulskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | korla
# Processing Record 41 of Set 2 | lusambo
# Processing Record 42 of Set 2 | ketchikan
# Processing Record 43 of Set 2 | faanui
# Processing Record 44 of Set 2 | limoux
# Processing Record 45 of Set 2 | kodiak
# Processing Record 46 of Set 2 | talnakh
# Processing Record 47 of Set 2 | ust-karsk
# Processing Record 48 of Set 2 | batemans bay
# Processing Record 49 of Set 2 | sal rei
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | hay river
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | okato
# Processing Record 5 of Set 3 | vila franca do campo
# Processing Record 6 of Set 3 | kahului
# Processing Record 7 of Set 3 | dryden
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 3 | sinjah
# City not found. Skipping...
# Processing Record 10 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 3 | port macquarie
# Processing Record 12 of Set 3 | laguna
# Processing Record 13 of Set 3 | hofn
# Processing Record 14 of Set 3 | talara
# Processing Record 15 of Set 3 | tazovskiy
# Processing Record 16 of Set 3 | eganville
# Processing Record 17 of Set 3 | urbana
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | hambantota
# Processing Record 20 of Set 3 | bonfim
# Processing Record 21 of Set 3 | sangar
# Processing Record 22 of Set 3 | shatki
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 25 of Set 3 | mananjary
# Processing Record 26 of Set 3 | neyshabur
# Processing Record 27 of Set 3 | mulanje
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 30 of Set 3 | kirakira
# Processing Record 31 of Set 3 | balestrand
# Processing Record 32 of Set 3 | egvekinot
# Processing Record 33 of Set 3 | bredasdorp
# Processing Record 34 of Set 3 | leningradskiy
# Processing Record 35 of Set 3 | zhanaozen
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 3 | te anau
# Processing Record 39 of Set 3 | cockburn town
# Processing Record 40 of Set 3 | astipalaia
# City not found. Skipping...
# Processing Record 41 of Set 3 | baykit
# Processing Record 42 of Set 3 | hope
# Processing Record 43 of Set 3 | luwuk
# Processing Record 44 of Set 3 | lingao
# Processing Record 45 of Set 3 | kintinku
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | tateyama
# Processing Record 48 of Set 3 | flin flon
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | mitsamiouli
# Processing Record 1 of Set 4 | alibag
# Processing Record 2 of Set 4 | isangel
# Processing Record 3 of Set 4 | colares
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | raudeberg
# Processing Record 6 of Set 4 | cobija
# Processing Record 7 of Set 4 | tongliao
# Processing Record 8 of Set 4 | natchitoches
# Processing Record 9 of Set 4 | bayonne
# Processing Record 10 of Set 4 | ahipara
# Processing Record 11 of Set 4 | klaksvik
# Processing Record 12 of Set 4 | nyurba
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | bushehr
# Processing Record 15 of Set 4 | caravelas
# Processing Record 16 of Set 4 | azare
# Processing Record 17 of Set 4 | mafeteng
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | khipro
# Processing Record 20 of Set 4 | payo
# Processing Record 21 of Set 4 | portland
# Processing Record 22 of Set 4 | fare
# Processing Record 23 of Set 4 | port blair
# Processing Record 24 of Set 4 | la ronge
# Processing Record 25 of Set 4 | male
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | beyneu
# Processing Record 28 of Set 4 | sumbe
# Processing Record 29 of Set 4 | lima
# Processing Record 30 of Set 4 | madimba
# Processing Record 31 of Set 4 | atuona
# Processing Record 32 of Set 4 | saldanha
# Processing Record 33 of Set 4 | beringovskiy
# Processing Record 34 of Set 4 | luderitz
# Processing Record 35 of Set 4 | pacific grove
# Processing Record 36 of Set 4 | mitu
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | north myrtle beach
# Processing Record 39 of Set 4 | shubarshi
# Processing Record 40 of Set 4 | yuncheng
# Processing Record 41 of Set 4 | thompson
# Processing Record 42 of Set 4 | sur
# Processing Record 43 of Set 4 | shikhazany
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | manzhouli
# Processing Record 46 of Set 4 | san patricio
# Processing Record 47 of Set 4 | berlevag
# Processing Record 48 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 4 | uhlove
# Processing Record 50 of Set 4 | zyryanka
# Processing Record 1 of Set 5 | merauke
# Processing Record 2 of Set 5 | flinders
# Processing Record 3 of Set 5 | nome
# Processing Record 4 of Set 5 | meulaboh
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | manggar
# Processing Record 7 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 5 | sabana de torres
# Processing Record 9 of Set 5 | albany
# Processing Record 10 of Set 5 | saskylakh
# Processing Record 11 of Set 5 | pljevlja
# Processing Record 12 of Set 5 | pestravka
# Processing Record 13 of Set 5 | shahr-e babak
# Processing Record 14 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 5 | paka
# Processing Record 16 of Set 5 | nabire
# Processing Record 17 of Set 5 | sokoni
# Processing Record 18 of Set 5 | belyy yar
# Processing Record 19 of Set 5 | vao
# Processing Record 20 of Set 5 | tambacounda
# Processing Record 21 of Set 5 | itarema
# Processing Record 22 of Set 5 | cimarron hills
# Processing Record 23 of Set 5 | alugan
# Processing Record 24 of Set 5 | havre-saint-pierre
# Processing Record 25 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | akyab
# Processing Record 27 of Set 5 | hami
# Processing Record 28 of Set 5 | alice springs
# Processing Record 29 of Set 5 | plouzane
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | honningsvag
# Processing Record 32 of Set 5 | banjar
# Processing Record 33 of Set 5 | borujan
# City not found. Skipping...
# Processing Record 34 of Set 5 | tilichiki
# Processing Record 35 of Set 5 | ginir
# Processing Record 36 of Set 5 | maniitsoq
# Processing Record 37 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 5 | taltal
# Processing Record 39 of Set 5 | hasaki
# Processing Record 40 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 41 of Set 5 | hualmay
# Processing Record 42 of Set 5 | sao filipe
# Processing Record 43 of Set 5 | sarkand
# Processing Record 44 of Set 5 | havelock
# Processing Record 45 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 5 | ornskoldsvik
# Processing Record 47 of Set 5 | sao joao da barra
# Processing Record 48 of Set 5 | matay
# Processing Record 49 of Set 5 | baherden
# Processing Record 50 of Set 5 | ponta do sol
# Processing Record 1 of Set 6 | mana
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | platonovka
# Processing Record 4 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 6 | ribnica
# Processing Record 6 of Set 6 | salta
# Processing Record 7 of Set 6 | souillac
# Processing Record 8 of Set 6 | vestmannaeyjar
# Processing Record 9 of Set 6 | sisimiut
# Processing Record 10 of Set 6 | geraldton
# Processing Record 11 of Set 6 | coruripe
# Processing Record 12 of Set 6 | spencer
# Processing Record 13 of Set 6 | hounde
# Processing Record 14 of Set 6 | gotsu
# Processing Record 15 of Set 6 | marzuq
# Processing Record 16 of Set 6 | bereda
# Processing Record 17 of Set 6 | penzance
# Processing Record 18 of Set 6 | voloshka
# Processing Record 19 of Set 6 | rincon
# Processing Record 20 of Set 6 | saint-pierre
# Processing Record 21 of Set 6 | cabo san lucas
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | cairns
# Processing Record 24 of Set 6 | avon
# Processing Record 25 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 6 | pemba
# Processing Record 27 of Set 6 | vrangel
# Processing Record 28 of Set 6 | riyadh
# Processing Record 29 of Set 6 | college
# Processing Record 30 of Set 6 | port-cartier
# Processing Record 31 of Set 6 | praia da vitoria
# Processing Record 32 of Set 6 | mnogovershinnyy
# Processing Record 33 of Set 6 | derveni
# Processing Record 34 of Set 6 | esqueda
# Processing Record 35 of Set 6 | villa carlos paz
# Processing Record 36 of Set 6 | ambulu
# Processing Record 37 of Set 6 | christchurch
# Processing Record 38 of Set 6 | longyearbyen
# Processing Record 39 of Set 6 | jiexiu
# Processing Record 40 of Set 6 | avera
# Processing Record 41 of Set 6 | galveston
# Processing Record 42 of Set 6 | kyabe
# Processing Record 43 of Set 6 | chicama
# Processing Record 44 of Set 6 | kudahuvadhoo
# Processing Record 45 of Set 6 | qinzhou
# Processing Record 46 of Set 6 | tocopilla
# Processing Record 47 of Set 6 | acajutla
# Processing Record 48 of Set 6 | malchevskaya
# Processing Record 49 of Set 6 | necochea
# Processing Record 50 of Set 6 | la gaulette
# City not found. Skipping...
# Processing Record 1 of Set 7 | tongren
# Processing Record 2 of Set 7 | turukhansk
# Processing Record 3 of Set 7 | ambilobe
# Processing Record 4 of Set 7 | chokurdakh
# Processing Record 5 of Set 7 | gillingham
# Processing Record 6 of Set 7 | lompoc
# Processing Record 7 of Set 7 | ariquemes
# Processing Record 8 of Set 7 | santo tomas
# Processing Record 9 of Set 7 | tautira
# Processing Record 10 of Set 7 | bunia
# Processing Record 11 of Set 7 | astara
# Processing Record 12 of Set 7 | hanmer springs
# Processing Record 13 of Set 7 | bainbridge
# Processing Record 14 of Set 7 | maldonado
# Processing Record 15 of Set 7 | lagoa
# Processing Record 16 of Set 7 | alyangula
# Processing Record 17 of Set 7 | dali
# Processing Record 18 of Set 7 | mount isa
# Processing Record 19 of Set 7 | pevek
# Processing Record 20 of Set 7 | sanghar
# Processing Record 21 of Set 7 | trairi
# Processing Record 22 of Set 7 | jiaojiang
# Processing Record 23 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 24 of Set 7 | thinadhoo
# Processing Record 25 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 7 | arlit
# Processing Record 27 of Set 7 | codrington
# Processing Record 28 of Set 7 | bangassou
# Processing Record 29 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 30 of Set 7 | bathsheba
# Processing Record 31 of Set 7 | santa ana
# Processing Record 32 of Set 7 | severo-kurilsk
# Processing Record 33 of Set 7 | zimovniki
# Processing Record 34 of Set 7 | khandyga
# Processing Record 35 of Set 7 | cruzilia
# Processing Record 36 of Set 7 | auki
# Processing Record 37 of Set 7 | alappuzha
# Processing Record 38 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 7 | perivolion
# Processing Record 40 of Set 7 | hobyo
# Processing Record 41 of Set 7 | lisakovsk
# Processing Record 42 of Set 7 | fairbanks
# Processing Record 43 of Set 7 | roscommon
# Processing Record 44 of Set 7 | panama city
# Processing Record 45 of Set 7 | imbituba
# Processing Record 46 of Set 7 | sola
# Processing Record 47 of Set 7 | lata
# Processing Record 48 of Set 7 | grootfontein
# Processing Record 49 of Set 7 | mokrous
# Processing Record 50 of Set 7 | pudozh
# Processing Record 1 of Set 8 | det udom
# Processing Record 2 of Set 8 | blagoveshchenka
# Processing Record 3 of Set 8 | shirgaon
# Processing Record 4 of Set 8 | banda aceh
# Processing Record 5 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 8 | chadan
# Processing Record 7 of Set 8 | ixtapa
# Processing Record 8 of Set 8 | santa isabel do rio negro
# Processing Record 9 of Set 8 | tessalit
# Processing Record 10 of Set 8 | bengkulu
# Processing Record 11 of Set 8 | gizo
# Processing Record 12 of Set 8 | uruzgan
# Processing Record 13 of Set 8 | tiksi
# Processing Record 14 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 15 of Set 8 | la asuncion
# Processing Record 16 of Set 8 | coihaique
# Processing Record 17 of Set 8 | umea
# Processing Record 18 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 8 | biak
# Processing Record 20 of Set 8 | popondetta
# Processing Record 21 of Set 8 | manati
# Processing Record 22 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 23 of Set 8 | broken hill
# Processing Record 24 of Set 8 | maumere
# Processing Record 25 of Set 8 | nizwa
# Processing Record 26 of Set 8 | labuhan
# Processing Record 27 of Set 8 | homnabad
# Processing Record 28 of Set 8 | graested
# Processing Record 29 of Set 8 | fortuna
# Processing Record 30 of Set 8 | imeni zhelyabova
# Processing Record 31 of Set 8 | birjand
# Processing Record 32 of Set 8 | horadiz
# Processing Record 33 of Set 8 | goderich
# Processing Record 34 of Set 8 | spornoye
# Processing Record 35 of Set 8 | margate
# Processing Record 36 of Set 8 | parana
# Processing Record 37 of Set 8 | yaan
# Processing Record 38 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 8 | terney
# Processing Record 40 of Set 8 | sibolga
# Processing Record 41 of Set 8 | axim
# Processing Record 42 of Set 8 | shu
# Processing Record 43 of Set 8 | riwaka
# Processing Record 44 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 45 of Set 8 | plainview
# Processing Record 46 of Set 8 | coquimbo
# Processing Record 47 of Set 8 | bethel
# Processing Record 48 of Set 8 | cap malheureux
# Processing Record 49 of Set 8 | nikologory
# Processing Record 50 of Set 8 | havre
# Processing Record 1 of Set 9 | extremoz
# Processing Record 2 of Set 9 | amahai
# Processing Record 3 of Set 9 | alofi
# Processing Record 4 of Set 9 | ust-omchug
# Processing Record 5 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 9 | obluche
# City not found. Skipping...
# Processing Record 7 of Set 9 | guerrero negro
# Processing Record 8 of Set 9 | pangnirtung
# Processing Record 9 of Set 9 | port hardy
# Processing Record 10 of Set 9 | half moon bay
# Processing Record 11 of Set 9 | lakhimpur
# Processing Record 12 of Set 9 | faya
# Processing Record 13 of Set 9 | chuy
# Processing Record 14 of Set 9 | sorland
# Processing Record 15 of Set 9 | nha trang
# Processing Record 16 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 9 | yumen
# Processing Record 18 of Set 9 | yatou
# Processing Record 19 of Set 9 | kisangani
# Processing Record 20 of Set 9 | winthrop
# Processing Record 21 of Set 9 | omboue
# Processing Record 22 of Set 9 | ihosy
# Processing Record 23 of Set 9 | benguela
# Processing Record 24 of Set 9 | oranjestad
# Processing Record 25 of Set 9 | koson
# Processing Record 26 of Set 9 | mugumu
# Processing Record 27 of Set 9 | linxia
# Processing Record 28 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 9 | sinnamary
# Processing Record 30 of Set 9 | puro
# Processing Record 31 of Set 9 | kununurra
# Processing Record 32 of Set 9 | kavieng
# Processing Record 33 of Set 9 | santiago del estero
# Processing Record 34 of Set 9 | lahaina
# Processing Record 35 of Set 9 | kirkwall
# Processing Record 36 of Set 9 | bodden town
# Processing Record 37 of Set 9 | tromso
# Processing Record 38 of Set 9 | buraydah
# Processing Record 39 of Set 9 | senanga
# Processing Record 40 of Set 9 | tevriz
# Processing Record 41 of Set 9 | litayen
# City not found. Skipping...
# Processing Record 42 of Set 9 | visby
# Processing Record 43 of Set 9 | waingapu
# Processing Record 44 of Set 9 | acari
# Processing Record 45 of Set 9 | kidal
# Processing Record 46 of Set 9 | swamimalai
# Processing Record 47 of Set 9 | zafra
# Processing Record 48 of Set 9 | udachnyy
# Processing Record 49 of Set 9 | rexburg
# Processing Record 50 of Set 9 | awassa
# Processing Record 1 of Set 10 | namibe
# Processing Record 2 of Set 10 | bollnas
# Processing Record 3 of Set 10 | hit
# Processing Record 4 of Set 10 | tecoanapa
# Processing Record 5 of Set 10 | dingle
# Processing Record 6 of Set 10 | soyo
# Processing Record 7 of Set 10 | atsiki
# City not found. Skipping...
# Processing Record 8 of Set 10 | san matias
# Processing Record 9 of Set 10 | sambava
# Processing Record 10 of Set 10 | vung tau
# Processing Record 11 of Set 10 | camacupa
# Processing Record 12 of Set 10 | whitehorse
# Processing Record 13 of Set 10 | tambovka
# Processing Record 14 of Set 10 | nampula
# Processing Record 15 of Set 10 | hakvik
# City not found. Skipping...
# Processing Record 16 of Set 10 | daugavpils
# Processing Record 17 of Set 10 | jardim
# Processing Record 18 of Set 10 | okhotsk
# Processing Record 19 of Set 10 | lewistown
# Processing Record 20 of Set 10 | canton
# Processing Record 21 of Set 10 | tigil
# Processing Record 22 of Set 10 | bouna
# Processing Record 23 of Set 10 | zhigansk
# Processing Record 24 of Set 10 | angoche
# Processing Record 25 of Set 10 | buritis
# Processing Record 26 of Set 10 | kenora
# Processing Record 27 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 10 | kingman
# Processing Record 29 of Set 10 | mirnyy
# Processing Record 30 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 10 | rio gallegos
# Processing Record 32 of Set 10 | ambovombe
# Processing Record 33 of Set 10 | narsaq
# Processing Record 34 of Set 10 | severnyy
# Processing Record 35 of Set 10 | paciran
# Processing Record 36 of Set 10 | villazon
# Processing Record 37 of Set 10 | leh
# Processing Record 38 of Set 10 | tiarei
# Processing Record 39 of Set 10 | maridi
# Processing Record 40 of Set 10 | seymchan
# Processing Record 41 of Set 10 | podporozhye
# Processing Record 42 of Set 10 | ozerne
# Processing Record 43 of Set 10 | ciucurova
# Processing Record 44 of Set 10 | tuatapere
# Processing Record 45 of Set 10 | port moresby
# Processing Record 46 of Set 10 | chufarovo
# Processing Record 47 of Set 10 | burnie
# Processing Record 48 of Set 10 | xichang
# Processing Record 49 of Set 10 | gat
# Processing Record 50 of Set 10 | razole
# Processing Record 1 of Set 11 | los llanos de aridane
# Processing Record 2 of Set 11 | fort nelson
# Processing Record 3 of Set 11 | cocobeach
# Processing Record 4 of Set 11 | hojai
# Processing Record 5 of Set 11 | usila
# City not found. Skipping...
# Processing Record 6 of Set 11 | kavaratti
# Processing Record 7 of Set 11 | montrose
# Processing Record 8 of Set 11 | snyder
# Processing Record 9 of Set 11 | dong hoi
# Processing Record 10 of Set 11 | salalah
# Processing Record 11 of Set 11 | bairiki
# Processing Record 12 of Set 11 | miranda
# Processing Record 13 of Set 11 | abrego
# Processing Record 14 of Set 11 | westport
# Processing Record 15 of Set 11 | umm lajj
# Processing Record 16 of Set 11 | mouila
# Processing Record 17 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 11 | atar
# Processing Record 19 of Set 11 | hoquiam
# Processing Record 20 of Set 11 | carahue
# Processing Record 21 of Set 11 | aksu
# Processing Record 22 of Set 11 | sioux lookout
# Processing Record 23 of Set 11 | port augusta
# Processing Record 24 of Set 11 | san quintin
# Processing Record 25 of Set 11 | cartagena del chaira
# Processing Record 26 of Set 11 | porto novo
# Processing Record 27 of Set 11 | san jose
# Processing Record 28 of Set 11 | novikovo
# Processing Record 29 of Set 11 | bela
# Processing Record 30 of Set 11 | dubai
# Processing Record 31 of Set 11 | adigeni
# Processing Record 32 of Set 11 | suntar
# Processing Record 33 of Set 11 | topchanchi
# Processing Record 34 of Set 11 | paamiut
# Processing Record 35 of Set 11 | bani walid
# Processing Record 36 of Set 11 | kota belud
# Processing Record 37 of Set 11 | kathu
# Processing Record 38 of Set 11 | bom jesus
# Processing Record 39 of Set 11 | lindi
# Processing Record 40 of Set 11 | petropavlovka
# Processing Record 41 of Set 11 | shimoda
# Processing Record 42 of Set 11 | majene
# Processing Record 43 of Set 11 | meiktila
# Processing Record 44 of Set 11 | ciledug
# City not found. Skipping...
# Processing Record 45 of Set 11 | tallahassee
# Processing Record 46 of Set 11 | hovd
# Processing Record 47 of Set 11 | liverpool
# Processing Record 48 of Set 11 | navirai
# Processing Record 49 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 11 | olinda
# Processing Record 1 of Set 12 | carutapera
# Processing Record 2 of Set 12 | palauig
# Processing Record 3 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 12 | buala
# Processing Record 5 of Set 12 | sebinkarahisar
# Processing Record 6 of Set 12 | kruisfontein
# Processing Record 7 of Set 12 | chai badan
# Processing Record 8 of Set 12 | port lincoln
# Processing Record 9 of Set 12 | mandalgovi
# Processing Record 10 of Set 12 | cadillac
# Processing Record 11 of Set 12 | chaihe
# Processing Record 12 of Set 12 | maebaru
# Processing Record 13 of Set 12 | saint-joseph
# Processing Record 14 of Set 12 | yermakovskoye
# Processing Record 15 of Set 12 | buenaventura
# Processing Record 16 of Set 12 | inta
# Processing Record 17 of Set 12 | deer lake
# Processing Record 18 of Set 12 | tabas
# Processing Record 19 of Set 12 | arica
# Processing Record 20 of Set 12 | nemuro
# Processing Record 21 of Set 12 | anton lizardo
# Processing Record 22 of Set 12 | ruiru
# Processing Record 23 of Set 12 | storslett
# Processing Record 24 of Set 12 | port-gentil
# Processing Record 25 of Set 12 | flers
# Processing Record 26 of Set 12 | roma
# Processing Record 27 of Set 12 | sao gabriel da cachoeira
# Processing Record 28 of Set 12 | papasquiaro
# City not found. Skipping...
# Processing Record 29 of Set 12 | ranong
# Processing Record 30 of Set 12 | yar-sale
# Processing Record 31 of Set 12 | marienburg
# Processing Record 32 of Set 12 | karratha
# Processing Record 33 of Set 12 | rabo de peixe
# Processing Record 34 of Set 12 | kapit
# Processing Record 35 of Set 12 | sovetskiy
# Processing Record 36 of Set 12 | nelson bay
# Processing Record 37 of Set 12 | hirado
# Processing Record 38 of Set 12 | ojo caliente
# Processing Record 39 of Set 12 | bosaso
# Processing Record 40 of Set 12 | lamar
# Processing Record 41 of Set 12 | touros
# Processing Record 42 of Set 12 | berdigestyakh
# Processing Record 43 of Set 12 | mandera
# Processing Record 44 of Set 12 | ulaanbaatar
# Processing Record 45 of Set 12 | japura
# Processing Record 46 of Set 12 | bekeshevskaya
# Processing Record 47 of Set 12 | vostok
# Processing Record 48 of Set 12 | atambua
# Processing Record 49 of Set 12 | santa cruz
# Processing Record 50 of Set 12 | wanning
# Processing Record 1 of Set 13 | bonnyville
# Processing Record 2 of Set 13 | punta de piedra
# Processing Record 3 of Set 13 | nalut
# Processing Record 4 of Set 13 | sao jose da coroa grande
# Processing Record 5 of Set 13 | lake havasu city
# Processing Record 6 of Set 13 | kikwit
# Processing Record 7 of Set 13 | neepawa
# Processing Record 8 of Set 13 | tacuati
# Processing Record 9 of Set 13 | saint-louis
# Processing Record 10 of Set 13 | bima
# Processing Record 11 of Set 13 | luganville
# Processing Record 12 of Set 13 | urdoma
# Processing Record 13 of Set 13 | liberal
# Processing Record 14 of Set 13 | xinqing
# Processing Record 15 of Set 13 | log
# Processing Record 16 of Set 13 | dhidhdhoo
# Processing Record 17 of Set 13 | presidencia roque saenz pena
# Processing Record 18 of Set 13 | severomuysk
# Processing Record 19 of Set 13 | beloha
# Processing Record 20 of Set 13 | alto araguaia
# Processing Record 21 of Set 13 | yenotayevka
# Processing Record 22 of Set 13 | zemio
# Processing Record 23 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 13 | ternate
# Processing Record 25 of Set 13 | shirokiy
# Processing Record 26 of Set 13 | sozopol
# Processing Record 27 of Set 13 | orlik
# Processing Record 28 of Set 13 | launceston
# Processing Record 29 of Set 13 | nishihara
# Processing Record 30 of Set 13 | antalaha
# Processing Record 31 of Set 13 | manchester
# Processing Record 32 of Set 13 | cornwall
# Processing Record 33 of Set 13 | saint-augustin
# Processing Record 34 of Set 13 | inuvik
# Processing Record 35 of Set 13 | kutum
# Processing Record 36 of Set 13 | neiafu
# Processing Record 37 of Set 13 | evensk
# Processing Record 38 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 13 | slobodskoy
# Processing Record 40 of Set 13 | cayenne
# Processing Record 41 of Set 13 | rawah
# Processing Record 42 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 13 | broome
# Processing Record 44 of Set 13 | haines junction
# Processing Record 45 of Set 13 | karatau
# Processing Record 46 of Set 13 | matara
# Processing Record 47 of Set 13 | adre
# Processing Record 48 of Set 13 | gobabis
# Processing Record 49 of Set 13 | melfort
# Processing Record 50 of Set 13 | beira
# Processing Record 1 of Set 14 | ipora
# Processing Record 2 of Set 14 | akhnur
# Processing Record 3 of Set 14 | soledar
# Processing Record 4 of Set 14 | jutai
# Processing Record 5 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 6 of Set 14 | boyolangu
# Processing Record 7 of Set 14 | tulum
# Processing Record 8 of Set 14 | warri
# Processing Record 9 of Set 14 | vilcun
# Processing Record 10 of Set 14 | jasper
# Processing Record 11 of Set 14 | san vicente
# Processing Record 12 of Set 14 | lastoursville
# Processing Record 13 of Set 14 | lazaro cardenas
# Processing Record 14 of Set 14 | sanford
# Processing Record 15 of Set 14 | comodoro rivadavia
# Processing Record 16 of Set 14 | kropotkin
# Processing Record 17 of Set 14 | assiniboia
# Processing Record 18 of Set 14 | den helder
# Processing Record 19 of Set 14 | kant
# Processing Record 20 of Set 14 | kawalu
# Processing Record 21 of Set 14 | srandakan
# Processing Record 22 of Set 14 | ciechanow
# Processing Record 23 of Set 14 | jacareacanga
# Processing Record 24 of Set 14 | yambio
# Processing Record 25 of Set 14 | rawson
# Processing Record 26 of Set 14 | jumla
# Processing Record 27 of Set 14 | shrewsbury
# Processing Record 28 of Set 14 | huarmey
# Processing Record 29 of Set 14 | adrar
# Processing Record 30 of Set 14 | morondava
# Processing Record 31 of Set 14 | logan lake
# Processing Record 32 of Set 14 | ocampo
# Processing Record 33 of Set 14 | esperance
# Processing Record 34 of Set 14 | clarence town
# Processing Record 35 of Set 14 | padang
# Processing Record 36 of Set 14 | bambanglipuro
# Processing Record 37 of Set 14 | road town
# Processing Record 38 of Set 14 | iracoubo
# Processing Record 39 of Set 14 | siilinjarvi
# Processing Record 40 of Set 14 | reading
# Processing Record 41 of Set 14 | vikesa
# Processing Record 42 of Set 14 | machilipatnam
# Processing Record 43 of Set 14 | bukama
# Processing Record 44 of Set 14 | mayo
# Processing Record 45 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 46 of Set 14 | mankato
# Processing Record 47 of Set 14 | tahta
# Processing Record 48 of Set 14 | bafq
# Processing Record 49 of Set 14 | virginia beach
# Processing Record 50 of Set 14 | port shepstone
# Processing Record 1 of Set 15 | zhireken
# Processing Record 2 of Set 15 | chato
# Processing Record 3 of Set 15 | nuevo progreso
# Processing Record 4 of Set 15 | moose factory
# Processing Record 5 of Set 15 | karangampel
# Processing Record 6 of Set 15 | bhatkal
# Processing Record 7 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 8 of Set 15 | jimenez
# Processing Record 9 of Set 15 | nova olimpia
# Processing Record 10 of Set 15 | henties bay
# Processing Record 11 of Set 15 | rocha
# Processing Record 12 of Set 15 | vanimo
# Processing Record 13 of Set 15 | danjiangkou
# Processing Record 14 of Set 15 | camacha
# Processing Record 15 of Set 15 | gillette
# Processing Record 16 of Set 15 | muroto
# Processing Record 17 of Set 15 | natal
# Processing Record 18 of Set 15 | hamirpur
# Processing Record 19 of Set 15 | quibdo
# Processing Record 20 of Set 15 | naivasha
# Processing Record 21 of Set 15 | alhaurin el grande
# Processing Record 22 of Set 15 | searcy
# Processing Record 23 of Set 15 | rybachiy
# Processing Record 24 of Set 15 | victor harbor
# Processing Record 25 of Set 15 | vardo
# Processing Record 26 of Set 15 | chapais
# Processing Record 27 of Set 15 | ewa beach
# Processing Record 28 of Set 15 | cap-aux-meules
# Processing Record 29 of Set 15 | shingu
# Processing Record 30 of Set 15 | pilar
# Processing Record 31 of Set 15 | hastings
# Processing Record 32 of Set 15 | paita
# Processing Record 33 of Set 15 | katherine
# Processing Record 34 of Set 15 | bafia
# Processing Record 35 of Set 15 | grand gaube
# Processing Record 36 of Set 15 | assos
# Processing Record 37 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 15 | port hedland
# Processing Record 39 of Set 15 | jiuquan
# Processing Record 40 of Set 15 | ponta delgada
# Processing Record 41 of Set 15 | ereymentau
# Processing Record 42 of Set 15 | chemal
# Processing Record 43 of Set 15 | miri
# Processing Record 44 of Set 15 | bacabal
# Processing Record 45 of Set 15 | lucapa
# Processing Record 46 of Set 15 | bar-le-duc
# Processing Record 47 of Set 15 | batasan
# Processing Record 48 of Set 15 | bell ville
# Processing Record 49 of Set 15 | shushenskoye
# Processing Record 50 of Set 15 | tanout
# Processing Record 1 of Set 16 | mbour
# Processing Record 2 of Set 16 | chapleau
# Processing Record 3 of Set 16 | villa maria
# Processing Record 4 of Set 16 | sete
# Processing Record 5 of Set 16 | staicele
# Processing Record 6 of Set 16 | burica
# City not found. Skipping...
# Processing Record 7 of Set 16 | antofagasta
# Processing Record 8 of Set 16 | cheyur
# City not found. Skipping...
# Processing Record 9 of Set 16 | fuyang
# Processing Record 10 of Set 16 | tuy hoa
# Processing Record 11 of Set 16 | jalu
# Processing Record 12 of Set 16 | planeta rica
# Processing Record 13 of Set 16 | augusto correa
# Processing Record 14 of Set 16 | lewisporte
# Processing Record 15 of Set 16 | ostersund
# Processing Record 16 of Set 16 | kommunisticheskiy
# Processing Record 17 of Set 16 | puerto santander
# Processing Record 18 of Set 16 | bose
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     71.02        80          80
# 1     Deputatskiy      RU  69.3000  139.9000     53.46        39          93
# 2        Teguldet      RU  57.3064   88.1667     59.77        89         100
# 3     Port Alfred      ZA -33.5906   26.8910     62.40        38          11
# 4          Najran      SA  17.4924   44.1277     79.43        23          61
# 5       Hithadhoo      MV  -0.6000   73.0833     81.95        77          62
# 6         Natchez      US  31.5604  -91.4032     75.42        94          40
# 7  Port Elizabeth      ZA -33.9180   25.5701     60.96        44          57
# 8         Mataura      NZ -46.1927  168.8643     50.49        72          92
# 9        Hamilton      US  39.1834  -84.5333     86.43        36           0
#
#    Wind Speed Current Description                 Date
# 0       13.27       moderate rain  2022-06-29 23:01:38
# 1        4.23     overcast clouds  2022-06-29 23:01:39
# 2        7.25     overcast clouds  2022-06-29 23:01:39
# 3        7.27          few clouds  2022-06-29 23:01:39
# 4        4.38       broken clouds  2022-06-29 23:01:40
# 5        8.41       broken clouds  2022-06-29 23:01:40
# 6        8.05       moderate rain  2022-06-29 23:01:41
# 7        6.08       broken clouds  2022-06-29 23:00:18
# 8       10.20     overcast clouds  2022-06-29 23:01:41
# 9        3.00           clear sky  2022-06-29 22:59:54

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
